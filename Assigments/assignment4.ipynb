# %% [markdown]
# ## Task 1: Rectangle class

# %%
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width
    
    def Perimeter(self):
        return 2 * (self.length + self.width)
    
    def Area(self):
        return self.length * self.width
    
    def display(self):
        print(f"Length: {self.length}")
        print(f"Width: {self.width}")
        print(f"Perimeter: {self.Perimeter()}")
        print(f"Area: {self.Area()}")

rect = Rectangle(5, 3)
rect.display()
print("\n")

class Parallelepipede(Rectangle):
    def __init__(self, length, width, height):
        super().__init__(length, width)
        self.height = height
    
    def Volume(self):
        return self.length * self.width * self.height
    
    def display(self):
        super().display()
        print(f"Height: {self.height}")
        print(f"Volume: {self.Volume()}")

parallelepipede = Parallelepipede(5, 3, 4)
parallelepipede.display()
print("\n")
# Out:
# Length: 5
# Width: 3
# Perimeter: 16
# Area: 15
#
#
# Length: 5
# Width: 3
# Perimeter: 16
# Area: 15
# Height: 4
# Volume: 60

# %% [markdown]
# ## Task 2: Person class and child Student class

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def display(self):
        print(f"Name: {self.name}")
        print(f"Age: {self.age}")

class Student(Person):
    def __init__(self, name, age, section):
        super().__init__(name, age)
        self.section = section
    
    def displayStudent(self):
        super().display()
        print(f"Section: {self.section}")

student = Student("John Doe", 20, "A")
student.displayStudent()
print("\n")
# Out:
# Name: John Doe
# Age: 20
# Section: A

# %% [markdown]
# ## Task 3: Computation class

# %%
class Computation:
    def __init__(self):
        pass
    
    def Factorial(self, n):
        if n == 0 or n == 1:
            return 1
        else:
            return n * self.Factorial(n - 1)
    
    def Sum(self, n):
        return n * (n + 1) // 2
    
    def testPrim(self, n):
        if n <= 1:
            return False
        for i in range(2, int(n ** 0.5) + 1):
            if n % i == 0:
                return False
        return True
    
    def testPrims(self, a, b):
        for i in range(2, min(a, b) + 1):
            if a % i == 0 and b % i == 0:
                return False
        return True
    
    def tableMult(self, n):
        for i in range(1, 11):
            print(f"{n} x {i} = {n * i}")
    
    def allTablesMult(self):
        for i in range(1, 10):
            print(f"\nMultiplication Table for {i}:")
            self.tableMult(i)
    
    @staticmethod
    def listDiv(n):
        return [i for i in range(1, n + 1) if n % i == 0]
    
    def listDivPrim(self, n):
        divisors = self.listDiv(n)
        return [i for i in divisors if self.testPrim(i)]

comp = Computation()
print(f"Factorial of 5: {comp.Factorial(5)}")
print(f"Sum of first 5 integers: {comp.Sum(5)}")
print(f"Is 17 a prime number? {comp.testPrim(17)}")
print(f"Are 17 and 23 prime between them? {comp.testPrims(17, 23)}")
print("\nMultiplication table for 3:")
comp.tableMult(3)
print("\nAll multiplication tables from 1 to 9:")
comp.allTablesMult()
print(f"Divisors of 12: {Computation.listDiv(12)}")
print(f"Prime divisors of 12: {comp.listDivPrim(12)}")
print("\n")
# Out:
# Factorial of 5: 120
# Sum of first 5 integers: 15
# Is 17 a prime number? True
# Are 17 and 23 prime between them? True
#
# Multiplication table for 3:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
#
# All multiplication tables from 1 to 9:
#
# Multiplication Table for 1:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
#
# Multiplication Table for 2:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
#
# Multiplication Table for 3:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
#
# Multiplication Table for 4:
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
#
# Multiplication Table for 5:
# ...

# %% [markdown]
# ## Task 4: Longest Common Subsequence

# %%
def longest_common_subsequence(str1, str2):
    m = len(str1)
    n = len(str2)
    
    dp = [[0] * (n + 1) for i in range(m + 1)]
    
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if str1[i - 1] == str2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])
    
    lcs = ""
    i, j = m, n
    while i > 0 and j > 0:
        if str1[i - 1] == str2[j - 1]:
            lcs = str1[i - 1] + lcs
            i -= 1
            j -= 1
        elif dp[i - 1][j] > dp[i][j - 1]:
            i -= 1
        else:
            j -= 1
    
    return lcs

str1 = "AGGTAB"
str2 = "GXTXAYB"
print(f"Longest Common Subsequence of '{str1}' and '{str2}': {longest_common_subsequence(str1, str2)}")
# Out:
# Longest Common Subsequence of 'AGGTAB' and 'GXTXAYB': GTAB
